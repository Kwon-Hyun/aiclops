# %% [markdown]
# ### 1. Image Augmentation

# %% [markdown]
# https://hoya012.github.io/blog/albumentation_tutorial/
# <br>해당 페이지를 참고했을 때, imgaug 방법 보다는 albumentations를 사용하는 것이 img augmentation에 적절하다는 판단

# %%
#pip install albumentations
# Out:
# Collecting albumentations
#   Downloading albumentations-1.4.18-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: numpy>=1.24.4 in /Users/hyunowk/opt/anaconda3/lib/python3.9/site-packages (from albumentations) (1.26.4)
# Collecting scipy>=1.10.0 (from albumentations)
#   Using cached scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (60 kB)
# Collecting scikit-image>=0.21.0 (from albumentations)
#   Downloading scikit_image-0.24.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: PyYAML in /Users/hyunowk/opt/anaconda3/lib/python3.9/site-packages (from albumentations) (6.0.1)
# Collecting pydantic>=2.7.0 (from albumentations)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting albucore==0.0.17 (from albumentations)
#   Downloading albucore-0.0.17-py3-none-any.whl.metadata (3.1 kB)
# Collecting eval-type-backport (from albumentations)
#   Downloading eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_12_0_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /Users/hyunowk/opt/anaconda3/lib/python3.9/site-packages (from albumentations) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hyunowk/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=2.7.0->albumentations) (0.6.0)
# Collecting pydantic-core==2.23.4 (from pydantic>=2.7.0->albumentations)
#   Downloading pydantic_core-2.23.4-cp39-cp39-macosx_10_12_x86_64.whl.metadata (6.6 kB)
# Collecting networkx>=2.8 (from scikit-image>=0.21.0->albumentations)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting pillow>=9.1 (from scikit-image>=0.21.0->albumentations)
#   Using cached pillow-10.4.0-cp39-cp39-macosx_10_10_x86_64.whl.metadata (9.2 kB)
# Collecting imageio>=2.33 (from scikit-image>=0.21.0->albumentations)
#   Downloading imageio-2.35.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.21.0->albumentations)
#   Downloading tifffile-2024.8.30-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /Users/hyunowk/opt/anaconda3/lib/python3.9/site-packages (from scikit-image>=0.21.0->albumentations) (23.2)
# Collecting lazy-loader>=0.4 (from scikit-image>=0.21.0->albumentations)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading albumentations-1.4.18-py3-none-any.whl (224 kB)
# Downloading albucore-0.0.17-py3-none-any.whl (10 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_12_0_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.8 MB/s eta 0:00:0000:0100:01
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp39-cp39-macosx_10_12_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.9 MB/s eta 0:00:00
# Downloading scikit_image-0.24.0-cp39-cp39-macosx_10_9_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 10.8 MB/s eta 0:00:0000:0100:01
# Using cached scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl (39.4 MB)
# Downloading eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Downloading imageio-2.35.1-py3-none-any.whl (315 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached pillow-10.4.0-cp39-cp39-macosx_10_10_x86_64.whl (3.5 MB)
# Downloading tifffile-2024.8.30-py3-none-any.whl (227 kB)
# Installing collected packages: tifffile, scipy, pydantic-core, pillow, opencv-python-headless, networkx, lazy-loader, eval-type-backport, pydantic, imageio, albucore, scikit-image, albumentations
#   Attempting uninstall: tifffile
#     Found existing installation: tifffile 2021.7.2
#     Uninstalling tifffile-2021.7.2:
#       Successfully uninstalled tifffile-2021.7.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.1
#     Uninstalling scipy-1.7.1:
#       Successfully uninstalled scipy-1.7.1
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.5
#     Uninstalling pydantic_core-2.14.5:
#       Successfully uninstalled pydantic_core-2.14.5
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.7.0.72
#     Uninstalling opencv-python-headless-4.7.0.72:
#       Successfully uninstalled opencv-python-headless-4.7.0.72
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.6.3
#     Uninstalling networkx-2.6.3:
#       Successfully uninstalled networkx-2.6.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.2
#     Uninstalling pydantic-2.5.2:
#       Successfully uninstalled pydantic-2.5.2
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.9.0
#     Uninstalling imageio-2.9.0:
#       Successfully uninstalled imageio-2.9.0
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.18.3
#     Uninstalling scikit-image-0.18.3:
#       Successfully uninstalled scikit-image-0.18.3
# Successfully installed albucore-0.0.17 albumentations-1.4.18 eval-type-backport-0.2.0 imageio-2.35.1 lazy-loader-0.4 networkx-3.2.1 opencv-python-headless-4.10.0.84 pillow-10.4.0 pydantic-2.9.2 pydantic-core-2.23.4 scikit-image-0.24.0 scipy-1.13.1 tifffile-2024.8.30
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv
import numpy as np
import os
import glob
import albumentations as albu

# %%
# Augmentation pipeline 정의 (회전, 뒤집기, 기울기 등 적용)
# 여기서 밝기, 색조 등 색에 영향을 끼칠 만한 요소는 제외하고 augmentation 진행

augmentation_pipeline = albu.Compose([
    albu.HorizontalFlip(p=0.5), # 50% 확률로 좌우 반전
    albu.RandomRotate90(p=0.5), # 90도 회전
    albu.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.1, rotate_limit=45, p=0.5), # 이미지 이동, 크기 조절, 회전
    albu.GaussNoise(p=0.2)  # 가우시안 노이즈 추가
])

# %%
def augment_images(image_set, output_path, num_augmented):
    # 출력할 img folder가 없으면 생성~
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    
    for i, img_path in enumerate(image_set):
        # 이미지 불러오기
        img = cv.imread(img_path)   #! img_path가 어딨농?

        if img is None:
            print(f"이미지 불러오기 실패!!! : {img_path}")
            continue
        
        for j in range(num_augmented):
            # augmentation 적용
            augmented = augmentation_pipeline(image=img)
            augmented_img = augmented['image']

            # 증강된 이미지 저장 경로 설정 및 저장
            output_file = os.path.join(output_path, f"augmented_{i}_{j}.jpg")
            cv.imwrite(output_file, augmented_img)

# %%
# image set augmentation

# 증강할 이미지 폴더 경로 설정
image_folder = '/Users/hyunowk/Downloads/aiclopse_hyun/img/*'

# glob을 이용해 이미지 경로 리스트 생성
image_paths = glob.glob(image_folder)

# %%
# image_folder 내 이미지들 각각 20번씩 증강하여 저장
augment_images(image_paths, 'output_folder', 20)

# %% [markdown]
# ### 2. 이미지 전처리 (Grayscale 및 mask 추출)

# %%
def process_images(input_folder):
    # 처리된 이미지를 저장할 폴더가 없으면 생성
    if not os.path.exists("processed_images"):
        os.makedirs("processed_images")
    
    if not os.path.exists("mask_images"):
        os.makedirs("mask_images")
    
    images = os.listdir(input_folder)

    for img_file in images:
        img_path = os.path.join(input_folder, img_file)
        img = cv.imread(img_path)

        if img is None:
            print(f"이미지를 불러올 수 없습니다: {img_path}")
            continue

        # 1. HSV 변환
        img_hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

        # 2. 보라색 범위 설정 (이전에 구해 놓은 범위로 파란색, 보라색 범위 구분해서 설정)
        # blue 범위
        lower_blue = np.array([100, 150, 0])
        upper_blue = np.array([140, 255, 255])

        # purple 범위
        lower_purple = np.array([125, 50, 70])
        upper_purple = np.array([150, 255, 255])

        # 3. 보라색 mask 생성
        blue_mask = cv.inRange(img_hsv, lower_blue, upper_blue)
        purple_mask = cv.inRange(img_hsv, lower_purple, upper_purple)

        # 4. 각 이미지가 보라색에 해당하면 보라색 마스크, 파란색에 해당하면 파란색 마스크 생성
        if cv.countNonZero(purple_mask) > 0:
            # 보라색 마스크가 있는 경우
            mask = purple_mask
            mask_color = "purple"
        elif cv.countNonZero(blue_mask) > 0:
            # 파란색 마스크가 있는 경우
            mask = blue_mask
            mask_color = "blue"
        else:
            print(f"{img_file}에서 파란색 또는 보라색이 감지되지 않았습니다.")
            continue

        # 5. 흑백 변환 (보라색 Mask 적용 후)
        img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_8_19.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_2.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_3_10.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_19.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_12_19.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_13_1.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_0.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_11_3.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_11_2.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_1.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_13_0.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_12_18.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_3_11.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_18.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_3.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_8_18.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_1_14.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_2_5.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_0_7.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_0_5.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_2_7.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_1_16.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_1.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_3_13.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_13_2.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_3.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_11_0.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_11_1.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_2.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_13_3.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_3_12.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_0.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_1_17.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_2_6.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_0_4.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_0_0.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_2_2.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_1_13.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_4.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_13_7.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_3_16.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_6.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_11_5.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_8_9.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_8_8.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_11_4.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_7.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_3_17.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_13_6.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_5.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_1_12.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_2_3.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_0_1.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_0_3.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_2_1.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_10_19.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_1_10.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_19.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_7.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_13_4.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_3_15.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_5.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_11_6.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_11_7.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_4.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_3_14.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_13_5.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_4_6.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_1_11.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_6_18.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_10_18.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_2_0.jpg의 purple 마스크 및 처리된 이미지 저장 완료
# augmented_0_2.jpg의 purple 마스크 및 처리된 이미지 저장 완료

# %% [markdown]
# ### 3. Threshold 및 Training

# %%
def find_threshold(mask_images):

    best_threshold = 0

    # 여러 이미지들에서 최적의 threshold 값을 찾아나가자-! (평균 계산으로 1차적으로 간단히 해봄)
    thresholds = []
    
    for mask_img in mask_images:

        if mask_img is None:
            print("이미지를 불러올 수 없습니다..")
            continue
        
        # 적절한 threshold 값 찾깅ㅋ (otsu 방식 적용)
        _, thresholded_img = cv.threshold(mask_img, 0, 255, cv.THRESH_BINARY + cv.THRESH_OTSU)
        thresholds.append(thresholded_img)
    
    # 전체 이미지의 평균 threshold값 구하기
    best_threshold = np.mean(thresholds)    # 평균
    return best_threshold

# %%
# mask 이미지 경로들
mask_images = [
    cv.imread('mask1.jpg', cv.IMREAD_GRAYSCALE), 
    cv.imread('mask2.jpg', cv.IMREAD_GRAYSCALE)
    ]

# 최적의 threshold 값 찾기
best_threshold = find_threshold(mask_images)

if best_threshold is not None:
    print("Best threshold: ", best_threshold)
else:
    print("Threshold 값을 계산할 수 없습니다.")
# Out:
# 이미지를 불러올 수 없습니다..
# 이미지를 불러올 수 없습니다..
# Best threshold:  nan
# [ WARN:0@950.118] global loadsave.cpp:241 findDecoder imread_('mask1.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@950.120] global loadsave.cpp:241 findDecoder imread_('mask2.jpg'): can't open/read file: check file path/integrity
# /Users/hyunowk/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/hyunowk/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### 4. 새로운 입력 이미지에 적용해보기

# %%
def detect_circle_in_new_image(new_image, threshold):
    hsv_image = cv.cvtColor(new_image, cv.COLOR_BGR2HSV)
    lower_purple = np.array([125, 50, 50])
    upper_purple = np.array([150, 255, 255])
    purple_mask = cv.inRange(hsv_image, lower_purple, upper_purple)

    # 학습된 threshold를 적용
    _, thresholded_img = cv.threshold(purple_mask, threshold, 255, cv.THRESH_BINARY)
    
    # 원 검출
    circles = cv.HoughCircles(thresholded_img, cv.HOUGH_GRADIENT, dp=1.2, minDist=30,
                               param1=50, param2=30, minRadius=10, maxRadius=100)
    
    if circles is not None:
        circles = np.round(circles[0, :]).astype("int")
        for (x, y, r) in circles:
            cv.circle(new_image, (x, y), r, (0, 255, 0), 4)

    cv.imshow('Detected Circles', new_image)
    cv.waitKey(0)
    cv.destroyAllWindows()

# 새로운 이미지에 대해 학습된 threshold 적용
new_img = cv.imread('new_laser_image.jpg')
detect_circle_in_new_image(new_img, best_threshold)
